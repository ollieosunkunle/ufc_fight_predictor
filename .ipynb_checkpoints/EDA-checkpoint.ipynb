# %%
#Import various useful libraries
import pandas as pd
import numpy as np

import datetime as dt
import matplotlib.pyplot as plt 
import datetime

import warnings
warnings.filterwarnings("ignore")

import seaborn as sns
from sqlalchemy import create_engine

# %%
sql_con = "sqlite:///database/ufc_data.db"
con = create_engine(sql_con)

# %%
min_df = pd.read_sql("SELECT * FROM train_df_min_data", con)

# %%
all_df = pd.read_sql("SELECT * FROM train_df_all_data", con)

# %%
min_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11548 entries, 0 to 11547
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   results               11548 non-null  object
#  1   fighter_1             11548 non-null  object
#  2   fighter_2             11548 non-null  object
#  3   direct_wins           11548 non-null  float64
#  4   direct_losses         11548 non-null  float64
#  5   ufc_f1-f2_wins        220 non-null    float64
#  6   all_f1-f2_wins        220 non-null    float64
#  7   ufc_f1-f2_losses      220 non-null    float64
#  8   all_f1-f2_losses      220 non-null    float64
#  9   ufc_f1-f2_fights      220 non-null    float64
#  10  all_f1-f2_fights      220 non-null    float64
#  11  f1-f2_no_kos          220 non-null    float64
#  12  f1-f2_ko_pct          11548 non-null  float64
#  13  f1-f2_no_subs         11548 non-null  float64
# ...

# %%
min_df.head()
# Out:
#   results      fighter_1      fighter_2  direct_wins  direct_losses  \
# 0     win  Patrick Smith  Johnny Rhodes          0.0            0.0
# 1     win   Royce Gracie  Jason DeLucia          0.0            0.0
# 2    loss   Royce Gracie  Patrick Smith          0.0            0.0
# 3    loss   Royce Gracie  Patrick Smith          0.0            0.0
# 4    loss   Royce Gracie  Patrick Smith          0.0            0.0
#
#    ufc_f1-f2_wins  all_f1-f2_wins  ufc_f1-f2_losses  all_f1-f2_losses  \
# 0             1.0            17.0               1.0              15.0
# 1             3.0           -22.0               3.0             -23.0
# 2             1.0            -8.0               1.0             -18.0
# 3             1.0            -8.0               1.0             -18.0
# 4             1.0            -8.0               1.0             -18.0
#
#    ufc_f1-f2_fights  ...  f1-f2_cum_td_diff  f1-f2_roll_td_diff  \
# 0               2.0  ...                0.0            0.000000
# ...

# %%
min_df.shape
# Out:
# (11548, 34)

# %%
min_df['results_num'] = np.where(min_df.results=='win',1,0)

# %%
min_df.columns
# Out:
# Index(['results', 'fighter_1', 'fighter_2', 'direct_wins', 'direct_losses',
#        'ufc_f1-f2_wins', 'all_f1-f2_wins', 'ufc_f1-f2_losses',
#        'all_f1-f2_losses', 'ufc_f1-f2_fights', 'all_f1-f2_fights',
#        'f1-f2_no_kos', 'f1-f2_ko_pct', 'f1-f2_no_subs', 'f1-f2_sub_pct',
#        'f1-f2_no_rounds', 'f1-f2_fight_time', 'f1-f2_no_strikes',
#        'f1-f2_cum_str_diff', 'f1-f2_roll_str_diff', 'f1-f2_cum_subs',
#        'f1-f2_cum_sub_diff', 'f1-f2_roll_sub_diff', 'f1-f2_cum_td',
#        'f1-f2_cum_td_diff', 'f1-f2_roll_td_diff', 'f1-f2_cum_pass',
#        'f1-f2_cum_pass_diff', 'f1-f2_roll_pass_diff', 'f1-f2_height',
#        'f1-f2_weight', 'f1-f2_reach', 'f1-f2_stance', 'f1-f2_dob',
#        'results_num'],
#       dtype='object')

# %%
cols = ['results_num', 'direct_wins', 'direct_losses',
       'ufc_f1-f2_wins', 'all_f1-f2_wins', 'ufc_f1-f2_losses',
       'all_f1-f2_losses', 'ufc_f1-f2_fights', 'all_f1-f2_fights',
       'f1-f2_no_kos', 'f1-f2_ko_pct', 'f1-f2_no_subs', 'f1-f2_sub_pct',
       'f1-f2_no_rounds', 'f1-f2_fight_time', 'f1-f2_no_strikes',
       'f1-f2_cum_str_diff', 'f1-f2_roll_str_diff', 'f1-f2_cum_subs',
       'f1-f2_cum_sub_diff', 'f1-f2_roll_sub_diff', 'f1-f2_cum_td',
       'f1-f2_cum_td_diff', 'f1-f2_roll_td_diff', 'f1-f2_cum_pass',
       'f1-f2_cum_pass_diff', 'f1-f2_roll_pass_diff', 'f1-f2_height',
       'f1-f2_weight', 'f1-f2_reach', 'f1-f2_stance', 'f1-f2_dob',
       'results_num']

# %%
fig,ax = plt.subplots(figsize=(15,15))

sns.heatmap(min_df[cols].corr())

# %% [markdown]
# 1. Insight -> should try removing the below, they are poorly correlated with direct wins/losses:
#     1. Reach
#     2. Stance
#     3. DOB

# %%
sns.catplot(data=min_df,y='f1-f2_dob',x='results_num',kind='point')

# %%
sns.catplot(data=min_df,y='f1-f2_stance',x='results_num',kind='point')

# %%
sns.catplot(data=min_df,y='ufc_f1-f2_wins',x='results_num',kind='point')

# %%
sns.catplot(data=min_df,y='all_f1-f2_wins',x='results_num',kind='point')

# %%
sns.catplot(data=min_df,y='direct_wins',x='results_num',kind='point')

# %%
sns.catplot(data=min_df,y='direct_losses',x='results_num',kind='bar')

# %%
sns.catplot(data=min_df,y='direct_losses',x='results_num',kind='bar')

# %%
min_df.columns
# Out:
# Index(['results', 'fighter_1', 'fighter_2', 'direct_wins', 'direct_losses',
#        'ufc_f1-f2_wins', 'all_f1-f2_wins', 'ufc_f1-f2_losses',
#        'all_f1-f2_losses', 'ufc_f1-f2_fights', 'all_f1-f2_fights',
#        'f1-f2_no_kos', 'f1-f2_ko_pct', 'f1-f2_no_subs', 'f1-f2_sub_pct',
#        'f1-f2_no_rounds', 'f1-f2_fight_time', 'f1-f2_no_strikes',
#        'f1-f2_cum_str_diff', 'f1-f2_roll_str_diff', 'f1-f2_cum_subs',
#        'f1-f2_cum_sub_diff', 'f1-f2_roll_sub_diff', 'f1-f2_cum_td',
#        'f1-f2_cum_td_diff', 'f1-f2_roll_td_diff', 'f1-f2_cum_pass',
#        'f1-f2_cum_pass_diff', 'f1-f2_roll_pass_diff', 'f1-f2_height',
#        'f1-f2_weight', 'f1-f2_reach', 'f1-f2_stance', 'f1-f2_dob',
#        'results_num'],
#       dtype='object')

# %%
min_df.head()
# Out:
#   results      fighter_1      fighter_2  direct_wins  direct_losses  \
# 0     win  Patrick Smith  Johnny Rhodes          0.0            0.0
# 1     win   Royce Gracie  Jason DeLucia          0.0            0.0
# 2    loss   Royce Gracie  Patrick Smith          0.0            0.0
# 3    loss   Royce Gracie  Patrick Smith          0.0            0.0
# 4    loss   Royce Gracie  Patrick Smith          0.0            0.0
#
#    ufc_f1-f2_wins  all_f1-f2_wins  ufc_f1-f2_losses  all_f1-f2_losses  \
# 0             1.0            17.0               1.0              15.0
# 1             3.0           -22.0               3.0             -23.0
# 2             1.0            -8.0               1.0             -18.0
# 3             1.0            -8.0               1.0             -18.0
# 4             1.0            -8.0               1.0             -18.0
#
#    ufc_f1-f2_fights  ...  f1-f2_roll_td_diff  f1-f2_cum_pass  \
# 0               2.0  ...            0.000000             1.0
# ...

# %%
min_df.loc[min_df.results=='win','ufc_f1-f2_wins'].mean()
# Out:
# 1.809090909090909

# %%
min_df.loc[min_df.results=='loss','ufc_f1-f2_wins'].mean()
# Out:
# 1.6818181818181819

# %%
min_df.results.value_counts()
# Out:
# win     5679
# loss    5679
# nc       110
# draw      80
# Name: results, dtype: int64

# %%
cols_to_plot = [
    'direct_wins', 'direct_losses',
       'ufc_f1-f2_wins', 'all_f1-f2_wins', 'ufc_f1-f2_losses',
       'all_f1-f2_losses', 'ufc_f1-f2_fights', 'all_f1-f2_fights',
       'f1-f2_no_kos', 'f1-f2_ko_pct', 'f1-f2_no_subs', 'f1-f2_sub_pct',
       'f1-f2_no_rounds', 'f1-f2_fight_time', 'f1-f2_no_strikes',
       'f1-f2_cum_str_diff', 'f1-f2_roll_str_diff', 'f1-f2_cum_subs',
       'f1-f2_cum_sub_diff', 'f1-f2_roll_sub_diff', 'f1-f2_cum_td',
       'f1-f2_cum_td_diff', 'f1-f2_roll_td_diff', 'f1-f2_cum_pass',
       'f1-f2_cum_pass_diff', 'f1-f2_roll_pass_diff', 'f1-f2_height',
       'f1-f2_weight', 'f1-f2_reach', 'f1-f2_stance', 'f1-f2_dob'
]

# %%
long_df = min_df.melt(id_vars=['results'],value_vars=cols_to_plot)

# %%
long_df.columns
# Out:
# Index(['results', 'variable', 'value'], dtype='object')

# %%
long_df.variable.value_counts()
# Out:
# f1-f2_cum_sub_diff      11548
# direct_losses           11548
# f1-f2_roll_str_diff     11548
# f1-f2_no_strikes        11548
# f1-f2_sub_pct           11548
# f1-f2_cum_td_diff       11548
# f1-f2_reach             11548
# direct_wins             11548
# f1-f2_cum_pass          11548
# f1-f2_weight            11548
# f1-f2_stance            11548
# f1-f2_roll_td_diff      11548
# all_f1-f2_wins          11548
# f1-f2_cum_subs          11548
# f1-f2_ko_pct            11548
# all_f1-f2_fights        11548
# ufc_f1-f2_fights        11548
# f1-f2_cum_td            11548
# f1-f2_roll_pass_diff    11548
# f1-f2_cum_pass_diff     11548
# ufc_f1-f2_wins          11548
# ufc_f1-f2_losses        11548
# all_f1-f2_losses        11548
# f1-f2_no_rounds         11548
# f1-f2_cum_str_diff      11548
# f1-f2_roll_sub_diff     11548
# f1-f2_height            11548
# f1-f2_no_kos            11548
# f1-f2_no_subs           11548
# f1-f2_fight_time        11548
# f1-f2_dob               11548
# ...

# %%
min_long_df = long_df.loc[(long_df.results.isin(['win','loss']))]

# %%
min_long_df.head()
# Out:
#       results        variable  value
# 23096     win  ufc_f1-f2_wins    1.0
# 23097     win  ufc_f1-f2_wins    3.0
# 23098    loss  ufc_f1-f2_wins    1.0
# 23099    loss  ufc_f1-f2_wins    1.0
# 23100    loss  ufc_f1-f2_wins    1.0

# %%
min_long_df[(min_long_df.variable=='ufc_f1-f2_wins') & (min_long_df.results=='win')].mean()
# Out:
# value    1.809091
# dtype: float64

# %%
min_long_df[(min_long_df.variable=='ufc_f1-f2_wins') & (min_long_df.results=='loss')].mean()
# Out:
# value    1.681818
# dtype: float64

# %%
print('column |','win |','loss |')
print('-'*20)
for i in cols_to_plot:
    print(i,'|', int(min_long_df[(min_long_df.variable==i) & (min_long_df.results=='win')].mean()*1000)/1000,'|',
         int(min_long_df[(min_long_df.variable==i) & (min_long_df.results=='loss')].mean()*1000)/1000)
# Out:
# column | win | loss |
# --------------------
# direct_wins | 0.014 | 0.014
# direct_losses | 0.014 | 0.014
# ufc_f1-f2_wins | 1.809 | 1.681
# all_f1-f2_wins | 11.263 | 11.136
# ufc_f1-f2_losses | 1.809 | 1.681
# all_f1-f2_losses | -1.3 | -1.427
# ufc_f1-f2_fights | 3.636 | 3.636
# all_f1-f2_fights | 9.963 | 9.709
# f1-f2_no_kos | 0.181 | 0.181
# f1-f2_ko_pct | -0.017 | -0.017
# f1-f2_no_subs | 0.035 | 0.035
# f1-f2_sub_pct | -0.008 | -0.008
# f1-f2_no_rounds | 2.2 | 2.727
# f1-f2_fight_time | 0.187 | 0.759
# f1-f2_no_strikes | 0.308 | 0.431
# f1-f2_cum_str_diff | 0.219 | 0.286
# f1-f2_roll_str_diff | 0.024 | 0.013
# f1-f2_cum_subs | 0.031 | 0.038
# f1-f2_cum_sub_diff | 0.0 | 0.0
# f1-f2_roll_sub_diff | 0.0 | 0.002
# f1-f2_cum_td | 0.037 | 0.043
# f1-f2_cum_td_diff | 0.027 | 0.029
# f1-f2_roll_td_diff | -0.001 | -0.001
# f1-f2_cum_pass | 0.061 | 0.071
# f1-f2_cum_pass_diff | 0.059 | 0.067
# f1-f2_roll_pass_diff | 0.004 | 0.006
# f1-f2_height | 0.272 | 0.272
# ...

# %% [markdown]
# Don't understand why so many variables are identical for both wins and losses. Need to investigate

# %%
for i in cols_to_plot:
    sns.catplot(data=min_long_df[min_long_df.variable.isin([i])],
                x='value', col='results',row='variable', kind='violin')
    plt.savefig('figures/'+i+'catplot.jpg')

# %%
for i in ['f1-f2_dob']:
    for j in ['win','loss']:
        sns.distplot(min_long_df[(min_long_df.results==j) & (min_long_df.variable.isin([i]))].value, hist=False, rug=True, label=j,kde_kws={"shade": True})

# %%
for i in ['ufc_f1-f2_losses']:
    for j in ['win','loss']:
        sns.distplot(min_long_df[(min_long_df.results==j) & (min_long_df.variable.isin([i]))].value, hist=False, rug=True, label=j,kde_kws={"shade": True})

# %%
for i in ['f1-f2_no_rounds']:
    for j in ['win','loss']:
        sns.distplot(min_long_df[(min_long_df.results==j) & (min_long_df.variable.isin([i]))].value, hist=False, rug=True, label=j,kde_kws={"shade": True})

# %%
for i in ['ufc_f1-f2_wins']:
    for j in ['win','loss']:
        sns.distplot(min_long_df[(min_long_df.results==j) & (min_long_df.variable.isin([i]))].value, hist=False, rug=True, label=j,kde_kws={"shade": True})

# %%
for i in ['f1-f2_reach']:
    for j in ['win','loss']:
        sns.distplot(min_long_df[(min_long_df.results==j) & (min_long_df.variable.isin([i]))].value, hist=False, rug=True, label=j,kde_kws={"shade": True})
