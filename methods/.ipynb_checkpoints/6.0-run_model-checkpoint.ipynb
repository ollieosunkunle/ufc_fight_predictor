# %%
#Import various useful libraries
import pandas as pd
import numpy as np

import datetime as dt
import datetime

from sqlalchemy import create_engine

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sql_con = "sqlite:///../database/ufc_data.db"
con = create_engine(sql_con)

# %%
test_df = pd.read_sql("SELECT * FROM test_df", con)

# %%
test_df.columns
# Out:
# Index(['fighter_1', 'fighter_2', 'f1_ufc_draw', 'f1_ufc_loss', 'f1_ufc_nc',
#        'f1_ufc_win', 'f1_height', 'f1_weight', 'f1_reach', 'f1_stance',
#        'f1_dob', 'f1_total_fights', 'f1_all_win', 'f1_all_loss', 'f1_all_draw',
#        'f1_ufc_total_fights', 'f1_cum_rnd', 'f1_cum_ftime', 'f1_cum_strikes',
#        'f1_cum_td', 'f1_cum_sub', 'f2_cum_rnd', 'f2_cum_ftime',
#        'f2_cum_strikes', 'f2_cum_td', 'f2_cum_sub', 'f1_stpm', 'f1_tdpm',
#        'f1_subpm', 'f2_stpm', 'f2_tdpm', 'f2_subpm', 'f1_win_streak',
#        'f1_loss_streak', 'f2_ufc_draw', 'f2_ufc_loss', 'f2_ufc_nc',
#        'f2_ufc_win', 'f2_height', 'f2_weight', 'f2_reach', 'f2_stance',
#        'f2_dob', 'f2_total_fights', 'f2_all_win', 'f2_all_loss', 'f2_all_draw',
#        'f2_ufc_total_fights', 'f2_win_streak', 'f2_loss_streak', 'd_ufc_draw',
#        'd_ufc_loss', 'd_ufc_nc', 'd_ufc_win', 'd_height', 'd_weight',
#        'd_reach', 'd_stance', 'd_dob', 'd_all_win', 'd_all_loss', 'd_all_draw',
#        'd_ufc_total_fights', 'd_cum_rnd', 'd_cum_ftime', 'd_cum_strikes',
#        'd_cum_td', 'd_cum_sub', 'd_stpm', 'd_tdpm', 'd_subpm', 'd_win_streak',
#        'd_loss_streak'],
#       dtype='object')

# %%
test_df
# Out:
#            fighter_1       fighter_2  f1_ufc_draw  f1_ufc_loss  f1_ufc_nc  \
# 0  Michelle Waterson     Angela Hill          0.0          3.0        0.0
# 1     Ottman Azaitar    Khama Worthy          0.0          0.0        0.0
# 2  Roxanne Modafferi      Andrea Lee          0.0          4.0        0.0
# 3          Ed Herman  Mike Rodriguez          0.0         10.0        0.0
# 4        Bobby Green    Alan Patrick          0.0          5.0        0.0
# 5  Billy Quarantillo     Kyle Nelson          0.0          0.0        0.0
# 6     Sijara Eubanks     Julia Avila          0.0          2.0        0.0
# 7       Jalin Turner     Brok Weaver          0.0          2.0        0.0
# 8    Bryan Barberena     Anthony Ivy          0.0          4.0        0.0
# 9        Sabina Mazo    Justine Kish          0.0          1.0        0.0
#
#    f1_ufc_win   f1_height  f1_weight    f1_reach  f1_stance  ...  d_cum_rnd  \
# 0         5.0  160.020004  52.163189  157.479996          1  ...       14.0
# 1         0.0  172.720001  70.306908  180.339996        100  ...       -2.0
# 2         3.0  170.179993  56.699116  175.259995          1  ...        3.0
# 3        11.0  185.419998  92.986549  195.580002          1  ...       46.0
# 4         5.0  177.800003  70.306908  180.339996          1  ...       -9.0
# 5         1.0  177.800003  65.770973  177.800003          1  ...        2.0
# 6         2.0  162.559998  61.235046  170.179993          1  ...        8.0
# 7         1.0  190.500000  70.306908  195.580002         10  ...        5.0
# 8         5.0  182.880005  77.110802  182.880005         10  ...       24.0
# 9         1.0  170.179993  56.699116  177.800003          1  ...       -6.0
#
#    d_cum_ftime  d_cum_strikes  d_cum_td  d_cum_sub      d_stpm    d_tdpm  \
# 0    45.283333           65.0       6.0        2.0   -5.147996  0.091673
# 1    -9.983333          -30.0      -3.0       -3.0  156.212625 -0.299003
# 2    10.083333          -18.0       0.0       -1.0   -6.049587  0.000000
# 3   130.983333          501.0      22.0       14.0   -1.396031  0.155899
# 4   -25.200000          -85.0     -18.0       -2.0    0.375083 -0.249499
# 5    10.100000           14.0       3.0        0.0   -2.522391  0.198238
# 6    30.250000          147.0       2.0        0.0   -6.195212 -0.200547
# 7    10.133333           67.0       0.0        1.0    2.562520  0.000000
# 8    75.616667          526.0       5.0        2.0  -21.813262 -1.183421
# 9   -20.166667          -18.0      -2.0       -2.0    3.371901  0.026446
#
#     d_subpm  d_win_streak  d_loss_streak
# 0  0.030558            -3              1
# 1 -0.299003            -1              0
# 2 -0.099174             1             -1
# 3  0.099209             1              0
# 4 -0.036069            -3              2
# 5  0.000000             1             -2
# 6 -0.199891            -1              2
# 7  0.065862            -1              1
# 8 -1.391802             0              1
# 9 -0.039669             1             -2
#
# [10 rows x 73 columns]

# %%
test_df_sub = test_df.drop(columns=['fighter_1','fighter_2'])

# %% [markdown]
# ## Experiments using Pycaret

# %%
from pycaret.classification import *

# %%
catboost = load_model('Final catboost Model 10Sep2020')
# Out:
# Transformation Pipeline and Model Sucessfully Loaded

# %%
predictions = predict_model(catboost, test_df)[['fighter_1','fighter_2','Label','Score']]

# %%
predictions['Certainty_pct'] = predictions.Score.apply(lambda x: (1-x)*200 if x >= 0.5 else x*200)

# %%
predictions['Winner'] = np.where(predictions['Label']==1,predictions['fighter_1'],predictions['fighter_2'])

# %%
predictions['Odds'] = np.where(predictions['Label']==1,predictions['Score']/(1-predictions['Score'])*100,(1-predictions['Score'])/predictions['Score']*100)

# %%
predictions
# Out:
#            fighter_1       fighter_2  Label   Score  Certainty  \
# 0  Michelle Waterson     Angela Hill      1  0.7290      54.20
# 1     Ottman Azaitar    Khama Worthy      1  0.7032      59.36
# 2  Roxanne Modafferi      Andrea Lee      0  0.2752      55.04
# 3          Ed Herman  Mike Rodriguez      0  0.3870      77.40
# 4        Bobby Green    Alan Patrick      0  0.1946      38.92
# 5  Billy Quarantillo     Kyle Nelson      1  0.7652      46.96
# 6     Sijara Eubanks     Julia Avila      0  0.2856      57.12
# 7       Jalin Turner     Brok Weaver      1  0.7421      51.58
# 8    Bryan Barberena     Anthony Ivy      0  0.4556      91.12
# 9        Sabina Mazo    Justine Kish      1  0.6772      64.56
#
#               Winner  Certainty_pct        Odds
# 0  Michelle Waterson          54.20  269.003690
# 1     Ottman Azaitar          59.36  236.927224
# 2         Andrea Lee          55.04  263.372093
# 3     Mike Rodriguez          77.40  158.397933
# 4       Alan Patrick          38.92  413.874615
# 5  Billy Quarantillo          46.96  325.894378
# 6        Julia Avila          57.12  250.140056
# 7       Jalin Turner          51.58  287.747189
# 8        Anthony Ivy          91.12  119.490781
# 9        Sabina Mazo          64.56  209.789343

# %%
predictions.to_sql('predictions',con,if_exists='replace',index=False)
