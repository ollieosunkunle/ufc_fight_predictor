# %%
#Scrape bout data -> uploads to sqlite database. Does not work properly because of reference error to database location
#%run "methods\1.0-scrape_bout_data-v2.0.ipynb"
# Out:
# 2020-07-26 19:43:58 [scrapy.utils.log] INFO: Scrapy 2.1.0 started (bot: scrapybot)
# 2020-07-26 19:43:58 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.20.0, Twisted 20.3.0, Python 3.7.7 (default, Apr 15 2020, 05:09:04) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.8, Platform Windows-10-10.0.18362-SP0
# 2020-07-26 19:43:58 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-07-26 19:43:58 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-07-26 19:43:58 [scrapy.extensions.telnet] INFO: Telnet Password: 6f9acefd96a31239
# 2020-07-26 19:43:58 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-07-26 19:43:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ...

# %%
#Scrape bout data -> uploads to sqlite database. Does not work properly because of reference error to database location
#%run "methods\1.1-scrape_fighter_data-v2.0.ipynb"
